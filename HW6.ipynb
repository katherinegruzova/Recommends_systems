# %% [markdown]
# Задание 1
# A) Попробуйте различные варианты генерации кандидатов. Какие из них дают наибольший recall@k ?
#
# Пока пробуем отобрать 50 кандидатов (k=50)
# Качество измеряем на data_val_lvl_1: следующие 6 недель после трейна
# Дают ли own recommendtions + top-popular лучший recall?
#
# B)* Как зависит recall@k от k? Постройте для одной схемы генерации кандидатов эту зависимость для k = {20, 50, 100, 200, 500}
# C)* Исходя из прошлого вопроса, как вы думаете, какое значение k является наиболее разумным?

# %%
# !pip install implicit
# Out:
# Requirement already satisfied: implicit in c:\users\ekate\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ekate\anaconda3\lib\site-packages (from implicit) (4.64.0)
# Requirement already satisfied: scipy>=0.16 in c:\users\ekate\anaconda3\lib\site-packages (from implicit) (1.7.3)
# Requirement already satisfied: numpy in c:\users\ekate\anaconda3\lib\site-packages (from implicit) (1.21.5)
# Requirement already satisfied: colorama in c:\users\ekate\anaconda3\lib\site-packages (from tqdm>=4.27->implicit) (0.4.4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pickle
import re

from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import csr_matrix, coo_matrix
import implicit
from implicit import als
from implicit.nearest_neighbours import ItemItemRecommender
from lightgbm import LGBMClassifier

import lightgbm as lgb

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

from metrics import precision_at_k, recall_at_k
from utils import prefilter_items
from recommenders import MainRecommender

import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('retail_train.csv')
item_features = pd.read_csv('product.csv')
user_features = pd.read_csv('hh_demographic.csv')

item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': 'item_id'}, inplace=True)
user_features.rename(columns={'household_key': 'user_id'}, inplace=True)

val_lvl_1_size_weeks = 6
val_lvl_2_size_weeks = 3

data_train_lvl_1 = data[data['week_no'] < data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)]
data_val_lvl_1 = data[(data['week_no'] >= data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)) &
                      (data['week_no'] < data['week_no'].max() - (val_lvl_2_size_weeks))]

data_train_lvl_2 = data_val_lvl_1.copy() 
data_val_lvl_2 = data[data['week_no'] >= data['week_no'].max() - val_lvl_2_size_weeks]

data_train_lvl_1.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0

# %%
def get_result_table(data: pd.DataFrame):
    result = data.groupby('user_id')['item_id'].unique().reset_index()
    result.columns = ['user_id', 'actual']
    return result

result_lvl_1 = get_result_table(data_val_lvl_1)
result_lvl_2 = get_result_table(data_val_lvl_2)
display(result_lvl_1.head(2), result_lvl_2.head(2))
# Out:
#    user_id                                             actual
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#    user_id                                             actual
# 0        1  [821867, 834484, 856942, 865456, 889248, 90795...
# 1        3  [835476, 851057, 872021, 878302, 879948, 90963...

# %%
n_items_before = data_train_lvl_1['item_id'].nunique()

data_train_lvl_1, top_n_popular = prefilter_items(data_train_lvl_1, item_features=item_features, take_n_popular=5000)

n_items_after = data_train_lvl_1['item_id'].nunique()
print('Decreased # items from {} to {}'.format(n_items_before, n_items_after))
# Out:
# Decreased # items from 83685 to 10086

# %%
common_users = data_train_lvl_1.user_id.values

data_val_lvl_1 = data_val_lvl_1[data_val_lvl_1.user_id.isin(common_users)]
data_train_lvl_2 = data_train_lvl_2[data_train_lvl_2.user_id.isin(common_users)]
data_val_lvl_2 = data_val_lvl_2[data_val_lvl_2.user_id.isin(common_users)]

# %%
recommender = MainRecommender(data_train_lvl_1, top_n_popular)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/5001 [00:00<?, ?it/s]

# %%
model_recs = recommender.get_model_recommendation()

# %%
similar_items_recs = recommender.get_similar_items_recommendation()

# %%
recall_at_k_dict = {}

k_list = [20, 50, 100, 200, 500]

for k in k_list:
    comp_name = 'model_rec_' + str(k)

    model_recs = \
        recommender.get_model_recommendation(N=k)

    result_lvl_1 = result_lvl_1.merge(model_recs,
                                      on='user_id',
                                      how='inner').rename(columns={'model_rec': comp_name})

    recall_at_k_dict[comp_name] = \
        result_lvl_1.apply(lambda row: recall_at_k(row[comp_name],
                                                   row['actual'], k=k), axis=1).mean()

# %%
recall_at_k_dict
# Out:
# {'model_rec_20': 0.03478771998011408,
#  'model_rec_50': 0.06581554103075965,
#  'model_rec_100': 0.09981077903362479,
#  'model_rec_200': 0.14556268212745618,
#  'model_rec_500': 0.22788611157569408}

# %%
for k in k_list:
    comp_name = 'similar_recommendation_' + str(k)

    similar_items_recs = \
        recommender.get_similar_items_recommendation(N=k)

    result_lvl_1 = result_lvl_1.merge(similar_items_recs,
                                      on='user_id',
                                      how='inner').rename(columns={'similar_recommendation': comp_name})

    recall_at_k_dict[comp_name] = \
        result_lvl_1.apply(lambda row: recall_at_k(row[comp_name],
                                                   row['actual'], k=k), axis=1).mean()

# %%
recall_at_k_dict
# Out:
# {'model_rec_20': 0.03478771998011408,
#  'model_rec_50': 0.06581554103075965,
#  'model_rec_100': 0.09981077903362479,
#  'model_rec_200': 0.14556268212745618,
#  'model_rec_500': 0.22788611157569408,
#  'similar_recommendation_20': 0.025150504663065645,
#  'similar_recommendation_50': 0.04909394737371636,
#  'similar_recommendation_100': 0.08119986479499786,
#  'similar_recommendation_200': 0.1320420874977376,
#  'similar_recommendation_500': 0.2160368866937793}

# %% [markdown]
# Задание 2.
#
# Обучите модель 2-ого уровня, при этом:
#     - Добавьте минимум по 2 фичи для юзера, товара и пары юзер-товар
#     - Измерьте отдельно precision@5 модели 1-ого уровня и двухуровневой модели на data_val_lvl_2
#     - Вырос ли precision@5 при использовании двухуровневой модели?

# %%
users_lvl_2 = pd.DataFrame(data_train_lvl_2['user_id'].unique())
users_lvl_2.columns = ['user_id']

# Пока только warm start
train_users = data_train_lvl_1['user_id'].unique()
users_lvl_2 = users_lvl_2[users_lvl_2['user_id'].isin(train_users)]

# %%
users_lvl_2 = users_lvl_2.merge(recommender.get_model_recommendation(N=500),
                                on='user_id',
                                how='inner')

users_lvl_2.columns = ['user_id', 'candidates']
users_lvl_2.head(2)
# Out:
#    user_id                                         candidates
# 0     2070  [1107553, 844165, 879755, 1053690, 1085604, 11...
# 1     2021  [871756, 981521, 1131344, 896938, 912681, 1037...

# %%
s = users_lvl_2.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'item_id'

users_lvl_2 = users_lvl_2.drop('candidates', axis=1).join(s)
users_lvl_2['flag'] = 1

users_lvl_2.head(4)
# Out:
#    user_id  item_id  flag
# 0     2070  1107553     1
# 0     2070   844165     1
# 0     2070   879755     1
# 0     2070  1053690     1

# %%
data_train_lvl_2.head(2)
# Out:
#          user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 2104867     2070  40618492260  594  1019940         1         1.00       311
# 2107468     2021  40618753059  594   840361         1         0.99       443
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 2104867        -0.29          40       86          0.0                0.0
# 2107468         0.00         101       86          0.0                0.0

# %%
targets_lvl_2 = data_train_lvl_2[['user_id', 'item_id', 'quantity', 'sales_value']].copy()
targets_lvl_2['target'] = 1  # тут только покупки

targets_lvl_2 = users_lvl_2.merge(targets_lvl_2, on=['user_id', 'item_id'], how='left')

targets_lvl_2['target'].fillna(0, inplace= True)
targets_lvl_2.drop('flag', axis=1, inplace=True)

targets_lvl_2.head(2)
# Out:
#    user_id  item_id  quantity  sales_value  target
# 0     2070  1107553       NaN          NaN     0.0
# 1     2070   844165       NaN          NaN     0.0

# %%
item_features.info(), user_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92353 entries, 0 to 92352
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   item_id               92353 non-null  int64
#  1   manufacturer          92353 non-null  int64
#  2   department            92353 non-null  object
#  3   brand                 92353 non-null  object
#  4   commodity_desc        92353 non-null  object
#  5   sub_commodity_desc    92353 non-null  object
#  6   curr_size_of_product  92353 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 4.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age_desc             801 non-null    object
#  1   marital_status_code  801 non-null    object
#  2   income_desc          801 non-null    object
#  3   homeowner_desc       801 non-null    object
#  4   hh_comp_desc         801 non-null    object
#  5   household_size_desc  801 non-null    object
#  6   kid_category_desc    801 non-null    object
#  7   user_id              801 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 50.2+ KB
# (None, None)

# %%
targets_lvl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1080418 entries, 0 to 1080417
# Data columns (total 5 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   user_id      1080418 non-null  int64
#  1   item_id      1080418 non-null  int64
#  2   quantity     42542 non-null    float64
#  3   sales_value  42542 non-null    float64
#  4   target       1080418 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 49.5 MB

# %%
targets_lvl_2 = targets_lvl_2.merge(item_features, on='item_id', how='left')
targets_lvl_2 = targets_lvl_2.merge(user_features, on='user_id', how='left')

targets_lvl_2.head(2)
# Out:
#    user_id  item_id  quantity  sales_value  target  manufacturer department  \
# 0     2070  1107553       NaN          NaN     0.0           103    GROCERY
# 1     2070   844165       NaN          NaN     0.0           103    GROCERY
#
#       brand commodity_desc              sub_commodity_desc  \
# 0  National    SOFT DRINKS  SFT DRNK SNGL SRV BTL CARB (EX
# 1  National    SOFT DRINKS  SFT DRNK 2 LITER BTL CARB INCL
#
#   curr_size_of_product age_desc marital_status_code income_desc  \
# 0                20 OZ    45-54                   U      50-74K
# 1                2 LTR    45-54                   U      50-74K
#
#   homeowner_desc hh_comp_desc household_size_desc kid_category_desc
# 0        Unknown      Unknown                   1      None/Unknown
# 1        Unknown      Unknown                   1      None/Unknown

# %%
targets_lvl_2['quantity'].fillna(targets_lvl_2['quantity'].median(),
                                 inplace=True)
targets_lvl_2['sales_value'].fillna(targets_lvl_2['sales_value'].mean(),
                                    inplace=True)

targets_lvl_2.info(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1080418 entries, 0 to 1080417
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   user_id               1080418 non-null  int64
#  1   item_id               1080418 non-null  int64
#  2   quantity              1080418 non-null  float64
#  3   sales_value           1080418 non-null  float64
#  4   target                1080418 non-null  float64
#  5   manufacturer          1080418 non-null  int64
#  6   department            1080418 non-null  object
#  7   brand                 1080418 non-null  object
#  8   commodity_desc        1080418 non-null  object
#  9   sub_commodity_desc    1080418 non-null  object
#  10  curr_size_of_product  1080418 non-null  object
#  11  age_desc              401633 non-null   object
#  12  marital_status_code   401633 non-null   object
#  13  income_desc           401633 non-null   object
#  14  homeowner_desc        401633 non-null   object
#  15  hh_comp_desc          401633 non-null   object
#  16  household_size_desc   401633 non-null   object
#  17  kid_category_desc     401633 non-null   object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 156.6+ MB

# %%
df = pd.pivot_table(targets_lvl_2,
                    index='user_id', columns='department',
                    values='quantity',
                    aggfunc='count',
                    fill_value=0)

df = df.idxmax(axis=1).reset_index()
df.columns = ['user_id', 'top_department']

targets_lvl_2 = targets_lvl_2.merge(df,
                                    on='user_id',
                                    how='inner')

# %%
df = pd.pivot_table(targets_lvl_2,
                    index='user_id', columns='brand',
                    values='quantity',
                    aggfunc='count',
                    fill_value=0)

df = df.idxmax(axis=1).reset_index()
df.columns = ['user_id', 'top_brand']

targets_lvl_2 = targets_lvl_2.merge(df,
                                    on='user_id',
                                    how='inner')

# %%
df = pd.pivot_table(targets_lvl_2,
                    index='user_id', columns='department',
                    values='sales_value',
                    aggfunc='mean',
                    fill_value=0
                    )

df = df.stack().reset_index()
df.columns = ['user_id', 'department', 'mean_sales_value_of_user_in_department']

targets_lvl_2 = targets_lvl_2.merge(df,
                                    on=['user_id', 'department'],
                                    how='inner')

# %%
targets_lvl_2['age_desc'].unique()
# Out:
# array(['45-54', nan, '35-44', '55-64', '25-34', '65+', '19-24'],
#       dtype=object)

# %%
df = \
    targets_lvl_2.groupby(by=['user_id'])['age_desc']\
    .apply(lambda x: pd.Series.mode(x))
df = df.reset_index()
df.drop(columns='level_1',
        inplace=True)

df.columns=['user_id', 'age_desc_corrected']

targets_lvl_2 = targets_lvl_2.merge(df,
                                    on='user_id',
                                    how='inner')

# %%
targets_lvl_2.head(2)
# Out:
#    user_id  item_id  quantity  sales_value  target  manufacturer department  \
# 0     2070  1107553       1.0     2.433413     0.0           103    GROCERY
# 1     2070   844165       1.0     2.433413     0.0           103    GROCERY
#
#       brand commodity_desc              sub_commodity_desc  ...  \
# 0  National    SOFT DRINKS  SFT DRNK SNGL SRV BTL CARB (EX  ...
# 1  National    SOFT DRINKS  SFT DRNK 2 LITER BTL CARB INCL  ...
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                   U      50-74K        Unknown      Unknown
# 1                   U      50-74K        Unknown      Unknown
#
#   household_size_desc kid_category_desc top_department top_brand  \
# 0                   1      None/Unknown        GROCERY  National
# 1                   1      None/Unknown        GROCERY  National
#
#   mean_sales_value_of_user_in_department age_desc_corrected
# 0                                2.37752              45-54
# 1                                2.37752              45-54
#
# [2 rows x 22 columns]

# %%
targets_lvl_2.columns
# Out:
# Index(['user_id', 'item_id', 'quantity', 'sales_value', 'target',
#        'manufacturer', 'department', 'brand', 'commodity_desc',
#        'sub_commodity_desc', 'curr_size_of_product', 'age_desc',
#        'marital_status_code', 'income_desc', 'homeowner_desc', 'hh_comp_desc',
#        'household_size_desc', 'kid_category_desc', 'top_department',
#        'top_brand', 'mean_sales_value_of_user_in_department',
#        'age_desc_corrected'],
#       dtype='object')

# %%
feature_columns = \
    ['user_id',
     'item_id',
     'quantity',
     'sales_value',
     'department',
     'manufacturer',
     'age_desc_corrected',
     'brand',
     'top_department',
     'top_brand',
     'mean_sales_value_of_user_in_department'
    ]

# %%
targets_lvl_2[feature_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401633 entries, 0 to 401632
# Data columns (total 11 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   user_id                                 401633 non-null  int64
#  1   item_id                                 401633 non-null  int64
#  2   quantity                                401633 non-null  float64
#  3   sales_value                             401633 non-null  float64
#  4   department                              401633 non-null  object
#  5   manufacturer                            401633 non-null  int64
#  6   age_desc_corrected                      401633 non-null  object
#  7   brand                                   401633 non-null  object
#  8   top_department                          401633 non-null  object
#  9   top_brand                               401633 non-null  object
#  10  mean_sales_value_of_user_in_department  401633 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 36.8+ MB

# %%
X_train = targets_lvl_2[feature_columns]
y_train = targets_lvl_2['target']

X_train.head(2)
# Out:
#    user_id  item_id  quantity  sales_value department  manufacturer  \
# 0     2070  1107553       1.0     2.433413    GROCERY           103
# 1     2070   844165       1.0     2.433413    GROCERY           103
#
#   age_desc_corrected     brand top_department top_brand  \
# 0              45-54  National        GROCERY  National
# 1              45-54  National        GROCERY  National
#
#    mean_sales_value_of_user_in_department
# 0                                 2.37752
# 1                                 2.37752

# %%
cat_feats = ['user_id', 'item_id', 'manufacturer',
              'age_desc_corrected', 'department',
             'brand', 'top_department','top_brand']

X_train[cat_feats] = X_train[cat_feats].astype('category')

# %%
X_train.isna().sum()
# Out:
# user_id                                   0
# item_id                                   0
# quantity                                  0
# sales_value                               0
# department                                0
# manufacturer                              0
# age_desc_corrected                        0
# brand                                     0
# top_department                            0
# top_brand                                 0
# mean_sales_value_of_user_in_department    0
# dtype: int64

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\ekate\anaconda3\lib\site-packages (1.2)
# Requirement already satisfied: matplotlib in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (3.5.1)
# Requirement already satisfied: scipy in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (1.7.3)
# Requirement already satisfied: plotly in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (5.6.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: six in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24 in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (1.4.2)
# Requirement already satisfied: graphviz in c:\users\ekate\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ekate\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ekate\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2021.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ekate\anaconda3\lib\site-packages (from matplotlib->catboost) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ekate\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\ekate\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ekate\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ekate\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ekate\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ekate\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %%
from catboost import CatBoostClassifier

# %%
result_lvl_2 = data_val_lvl_2.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_2.columns = ['user_id', 'actual']
result_lvl_2.head(5)
# Out:
#    user_id                                             actual
# 0        1  [821867, 834484, 856942, 865456, 889248, 90795...
# 1        3  [835476, 851057, 872021, 878302, 879948, 90963...
# 2        6  [920308, 926804, 946489, 1006718, 1017061, 107...
# 3        7  [840386, 889774, 898068, 909714, 929067, 95347...
# 4        8  [835098, 872137, 910439, 924610, 992977, 10412...

# %%
def map_at_k(recommended_list, bought_list, k=5):
    flags = np.isin(np.array(recommended_list), np.array(bought_list))
    if sum(flags) == 0:
        return 0
    sum_ = 0
    for i in range(min(k, len(flags))):
        if flags[i]:
            p_k = precision_at_k(recommended_list, bought_list, k=i+1)
            sum_ += p_k
    return sum_ / k

# %%
table_metric = {'iterations':[], 'learning_rate':[], 'depth':[],'Precision@5':[], 'MAP@5':[]}

for iterations_ in [50, 150, 300]:
  for learning_rate_ in [0.001, 0.015, 0.05]:
    for depth_ in [5, 10, 15]:
      model_ = CatBoostClassifier(
        random_seed=55,
        iterations=iterations_,
        learning_rate=learning_rate_,
        depth=depth_)

      model_.fit(X_train, y_train,
              cat_features=cat_feats,
              verbose=50)
      train_preds_ = model_.predict(X_train)
      train_preds_ = train_preds_.astype(bool)

      rec_items_ = X_train[train_preds_].groupby(by=['user_id'])['item_id'].unique().reset_index()
      rec_items_.columns = ['user_id', f'model_preds_iter_{iterations_}_rate{learning_rate_}_depth{depth_}']

      rec_items_[f'model_preds_iter_{iterations_}_rate{learning_rate_}_depth{depth_}'] = \
      rec_items_[f'model_preds_iter_{iterations_}_rate{learning_rate_}_depth{depth_}'].apply(lambda x: x[:5] if len(x) >= 5 else x)

      result_lvl_2 = result_lvl_2.merge(rec_items_,
                                   on='user_id',
                                   how='inner')

      test_presicion_ = result_lvl_2.apply(lambda row: precision_at_k(row[f'model_preds_iter_{iterations_}_rate{learning_rate_}_depth{depth_}'], row['actual']), axis=1).mean()
      test_map = result_lvl_2.apply(lambda row:  map_at_k(row[f'model_preds_iter_{iterations_}_rate{learning_rate_}_depth{depth_}'], row['actual']), axis=1).mean()

      table_metric['iterations'].append(iterations_)
      table_metric['learning_rate'].append(learning_rate_)
      table_metric['depth'].append(depth_)
      table_metric['Precision@5'].append(test_presicion_)
      table_metric['MAP@5'].append(test_map)
# Out:
# 0:	learn: 0.6921492	total: 227ms	remaining: 11.1s
# 49:	learn: 0.6455774	total: 2.58s	remaining: 0us
# 0:	learn: 0.6921492	total: 68.4ms	remaining: 3.35s
# 49:	learn: 0.6455980	total: 2.92s	remaining: 0us
# 0:	learn: 0.6921492	total: 65.1ms	remaining: 3.19s
# 49:	learn: 0.6455924	total: 3.79s	remaining: 0us
# 0:	learn: 0.6782820	total: 60.4ms	remaining: 2.96s
# 49:	learn: 0.2688427	total: 2.4s	remaining: 0us
# 0:	learn: 0.6782820	total: 60.5ms	remaining: 2.96s
# 49:	learn: 0.2689607	total: 2.92s	remaining: 0us
# 0:	learn: 0.6782820	total: 61.7ms	remaining: 3.02s
# 49:	learn: 0.2689807	total: 3.77s	remaining: 0us
# 0:	learn: 0.6444698	total: 60.8ms	remaining: 2.98s
# 49:	learn: 0.0414574	total: 2.48s	remaining: 0us
# 0:	learn: 0.6444698	total: 60.5ms	remaining: 2.97s
# 49:	learn: 0.0414886	total: 3.1s	remaining: 0us
# 0:	learn: 0.6444698	total: 61.9ms	remaining: 3.04s
# 49:	learn: 0.0415213	total: 4.1s	remaining: 0us
# 0:	learn: 0.6921492	total: 66ms	remaining: 9.83s
# 50:	learn: 0.6446716	total: 2.44s	remaining: 4.74s
# 100:	learn: 0.6015113	total: 5.1s	remaining: 2.47s
# 149:	learn: 0.5628890	total: 7.77s	remaining: 0us
# 0:	learn: 0.6921492	total: 64ms	remaining: 9.54s
# 50:	learn: 0.6446924	total: 3.21s	remaining: 6.24s
# 100:	learn: 0.6015348	total: 6.64s	remaining: 3.22s
# 149:	learn: 0.5629012	total: 9.92s	remaining: 0us
# 0:	learn: 0.6921492	total: 58.8ms	remaining: 8.77s
# 50:	learn: 0.6446896	total: 4.27s	remaining: 8.28s
# 100:	learn: 0.6015431	total: 8.72s	remaining: 4.23s
# 149:	learn: 0.5629095	total: 13.2s	remaining: 0us
# 0:	learn: 0.6782820	total: 61.8ms	remaining: 9.21s
# 50:	learn: 0.2642547	total: 2.94s	remaining: 5.71s
# 100:	learn: 0.1162396	total: 6.35s	remaining: 3.08s
# 149:	learn: 0.0541432	total: 9.48s	remaining: 0us
# 0:	learn: 0.6782820	total: 64.9ms	remaining: 9.66s
# 50:	learn: 0.2644087	total: 4.08s	remaining: 7.92s
# 100:	learn: 0.1163763	total: 7.67s	remaining: 3.72s
# 149:	learn: 0.0542101	total: 11s	remaining: 0us
# 0:	learn: 0.6782820	total: 64.2ms	remaining: 9.57s
# 50:	learn: 0.2644138	total: 4.42s	remaining: 8.59s
# 100:	learn: 0.1163430	total: 7.87s	remaining: 3.82s
# 149:	learn: 0.0541983	total: 12.2s	remaining: 0us
# 0:	learn: 0.6444698	total: 63.8ms	remaining: 9.5s
# 50:	learn: 0.0393942	total: 3.09s	remaining: 6s
# 100:	learn: 0.0032086	total: 6.34s	remaining: 3.08s
# 149:	learn: 0.0002991	total: 9.78s	remaining: 0us
# 0:	learn: 0.6444698	total: 72.3ms	remaining: 10.8s
# 50:	learn: 0.0394334	total: 4.17s	remaining: 8.1s
# 100:	learn: 0.0032271	total: 9s	remaining: 4.37s
# 149:	learn: 0.0003037	total: 13.9s	remaining: 0us
# 0:	learn: 0.6444698	total: 66.6ms	remaining: 9.93s
# 50:	learn: 0.0394546	total: 5.56s	remaining: 10.8s
# 100:	learn: 0.0032287	total: 10.9s	remaining: 5.28s
# 149:	learn: 0.0003049	total: 16.2s	remaining: 0us
# 0:	learn: 0.6889766	total: 217ms	remaining: 1m 5s
# 50:	learn: 0.5060569	total: 10s	remaining: 48.9s
# 100:	learn: 0.3680501	total: 19.9s	remaining: 39.2s
# 150:	learn: 0.2666553	total: 29.8s	remaining: 29.4s
# 200:	learn: 0.1901482	total: 39.8s	remaining: 19.6s
# 250:	learn: 0.1352949	total: 49s	remaining: 9.57s
# 299:	learn: 0.0943888	total: 58s	remaining: 0us
# 0:	learn: 0.6889787	total: 405ms	remaining: 2m 1s
# 50:	learn: 0.5115790	total: 13.2s	remaining: 1m 4s
# 100:	learn: 0.3708877	total: 25.3s	remaining: 49.9s
# 150:	learn: 0.2633752	total: 37.6s	remaining: 37.1s
# 200:	learn: 0.1856627	total: 49.7s	remaining: 24.5s
# 250:	learn: 0.1304976	total: 1m 1s	remaining: 12.1s
# 299:	learn: 0.0926335	total: 1m 13s	remaining: 0us
# 0:	learn: 0.6889787	total: 425ms	remaining: 2m 7s
# 50:	learn: 0.5091918	total: 17.1s	remaining: 1m 23s
# 100:	learn: 0.3667406	total: 31.8s	remaining: 1m 2s
# 150:	learn: 0.2623167	total: 48.3s	remaining: 47.7s
# 200:	learn: 0.1885579	total: 1m 1s	remaining: 30.2s
# 250:	learn: 0.1320096	total: 1m 13s	remaining: 14.4s
# 299:	learn: 0.0933285	total: 1m 31s	remaining: 0us
# 0:	learn: 0.6324240	total: 178ms	remaining: 53.3s
# 50:	learn: 0.0029794	total: 7.87s	remaining: 38.4s
# 100:	learn: 0.0001119	total: 14.4s	remaining: 28.3s
# 150:	learn: 0.0000279	total: 20.2s	remaining: 20s
# 200:	learn: 0.0000155	total: 26.7s	remaining: 13.1s
# 250:	learn: 0.0000120	total: 32.9s	remaining: 6.42s
# 299:	learn: 0.0000104	total: 38.7s	remaining: 0us
# 0:	learn: 0.6324538	total: 392ms	remaining: 1m 57s
# 50:	learn: 0.0030315	total: 15.1s	remaining: 1m 13s
# 100:	learn: 0.0001135	total: 29.9s	remaining: 58.9s
# 150:	learn: 0.0000298	total: 44.6s	remaining: 44s
# 200:	learn: 0.0000168	total: 58s	remaining: 28.6s
# 250:	learn: 0.0000152	total: 1m 11s	remaining: 13.9s
# 299:	learn: 0.0000138	total: 1m 23s	remaining: 0us
# 0:	learn: 0.6324538	total: 359ms	remaining: 1m 47s
# 50:	learn: 0.0032567	total: 14.3s	remaining: 1m 9s
# 100:	learn: 0.0001331	total: 37.7s	remaining: 1m 14s
# 150:	learn: 0.0000381	total: 58s	remaining: 57.2s
# 200:	learn: 0.0000225	total: 1m 23s	remaining: 41.2s
# 250:	learn: 0.0000204	total: 1m 45s	remaining: 20.5s
# 299:	learn: 0.0000204	total: 2m 7s	remaining: 0us
# 0:	learn: 0.5058927	total: 178ms	remaining: 53.1s
# 50:	learn: 0.0000262	total: 7.68s	remaining: 37.5s
# 100:	learn: 0.0000126	total: 13.7s	remaining: 26.9s
# 150:	learn: 0.0000115	total: 19.5s	remaining: 19.2s
# 200:	learn: 0.0000112	total: 25.3s	remaining: 12.5s
# 250:	learn: 0.0000112	total: 30.9s	remaining: 6.04s
# 299:	learn: 0.0000112	total: 36.1s	remaining: 0us
# 0:	learn: 0.5059781	total: 364ms	remaining: 1m 48s
# 50:	learn: 0.0000237	total: 17.3s	remaining: 1m 24s
# 100:	learn: 0.0000150	total: 36s	remaining: 1m 10s
# 150:	learn: 0.0000150	total: 53.6s	remaining: 52.9s
# 200:	learn: 0.0000150	total: 1m 11s	remaining: 35.1s
# 250:	learn: 0.0000150	total: 1m 28s	remaining: 17.2s
# 299:	learn: 0.0000150	total: 1m 44s	remaining: 0us
# 0:	learn: 0.5059781	total: 385ms	remaining: 1m 55s
# 50:	learn: 0.0000302	total: 16.4s	remaining: 1m 19s
# 100:	learn: 0.0000180	total: 41.2s	remaining: 1m 21s
# 150:	learn: 0.0000172	total: 1m 4s	remaining: 1m 3s
# 200:	learn: 0.0000151	total: 1m 32s	remaining: 45.8s
# 250:	learn: 0.0000144	total: 2m 1s	remaining: 23.7s
# 299:	learn: 0.0000136	total: 2m 37s	remaining: 0us

# %%
table_metric = pd.DataFrame(table_metric)
table_metric.sort_values(by=['Precision@5'], ascending=False)
# Out:
#     iterations  learning_rate  depth  Precision@5     MAP@5
# 2           50          0.001     15     0.330511  0.232360
# 5           50          0.015     15     0.330511  0.232360
# 0           50          0.001      5     0.330242  0.231987
# 11         150          0.001     15     0.330242  0.231987
# 20         300          0.001     15     0.330242  0.231987
# 19         300          0.001     10     0.330242  0.231987
# 18         300          0.001      5     0.330242  0.231987
# 14         150          0.015     15     0.330242  0.231987
# 1           50          0.001     10     0.330242  0.232096
# 12         150          0.015      5     0.330242  0.231987
# 13         150          0.015     10     0.330242  0.231772
# 10         150          0.001     10     0.330242  0.231987
# 9          150          0.001      5     0.330242  0.231987
# 8           50          0.050     15     0.330242  0.231772
# 7           50          0.050     10     0.330242  0.231772
# 6           50          0.050      5     0.330242  0.231772
# 4           50          0.015     10     0.330242  0.231987
# 3           50          0.015      5     0.330242  0.231987
# 15         150          0.050      5     0.329973  0.231553
# 16         150          0.050     10     0.329973  0.231553
# 17         150          0.050     15     0.329973  0.231553
# 21         300          0.015      5     0.329973  0.231553
# 22         300          0.015     10     0.329973  0.231553
# 23         300          0.015     15     0.329973  0.231553
# 24         300          0.050      5     0.329973  0.231553
# 25         300          0.050     10     0.329973  0.231553
# 26         300          0.050     15     0.329973  0.231553
